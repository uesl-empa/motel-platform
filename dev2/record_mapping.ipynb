# %% [markdown]
# # to map the 'unmapped record' to 'mapped record'
#
# NOTE:
#  - the 'mapped record' is based on a single source, but could be multiple attriutes
#
# Input: 'unmapped_record.yaml'
# Output: 'mapped_record' and link/add/modify other linked datasets
#
# workflow:
#  1. map to linked dataset: i.e. technology, process, source; attribute, temporal_scope, capacity_scope, system_boundary, carrier; via 3 options: link/add/modify
#  2. change the structure that each 'mapped_record' is based on a source, then create the new 'mapped_record'
#
# NOTE:
#  - the mapping 'for reFuel' can be done in previous step, using LLMs
#  - in the future, LLMs can be used by providing existing dataset, and the list of parameters to be checke (e.g. the same as previous step?)

# %%
## TODO: the step one can be done in previous step
